# %%
#Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Runs after uploading the dataset
! mkdir data
! unzip life-expectancy-who.zip  -d data
# Out:
# Archive:  life-expectancy-who.zip
#   inflating: data/Life Expectancy Data.csv

# %%
import warnings

warnings.filterwarnings('ignore', category=Warning)  # Ignore all warnings

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df = pd.read_csv('/content/life-expectancy-who.zip')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
ls
# Out:
# data/  life-expectancy-who.zip  sample_data/

# %%
pd.set_option("display.max_columns",None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
#Checking if there are duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# **Data Cleaning**

# %%
#Dealing with null values
col_with_null_values = ['Life expectancy ', 'Adult Mortality', 'Alcohol', 'Hepatitis B', ' BMI ', 'Polio', 'Total expenditure',
       'Diphtheria ', 'GDP', 'Population',' thinness  1-19 years', ' thinness 5-9 years','Income composition of resources', 'Schooling']
for i in col_with_null_values:
    mean = df[i].mean()
    df[i].fillna(value=mean, inplace = True)

# %%
#Removing spaces on data columns' names
df.rename(columns={" BMI ":"BMI","Life expectancy ":"Life_Expectancy","Adult Mortality":"Adult_Mortality",
                   "infant deaths":"Infant_Deaths","percentage expenditure":"Percentage_Exp","Hepatitis B":"HepatitisB",
                  "Measles ":"Measles"," BMI ":"BMI","under-five deaths ":"Under_Five_Deaths","Diphtheria ":"Diphtheria",
                  " HIV/AIDS":"HIV/AIDS"," thinness  1-19 years":"thinness_1to19_years"," thinness 5-9 years":"thinness_5to9_years","Income composition of resources":"Income_Comp_Of_Resources",
                   "Total expenditure":"Tot_Exp"},inplace=True)
df.head()
# Out:
#        Country  Year      Status  Life_Expectancy  Adult_Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant_Deaths  Alcohol  Percentage_Exp  HepatitisB  Measles   BMI  \
# 0             62     0.01       71.279624        65.0     1154  19.1
# 1             64     0.01       73.523582        62.0      492  18.6
# 2             66     0.01       73.219243        64.0      430  18.1
# 3             69     0.01       78.184215        67.0     2787  17.6
# 4             71     0.01        7.097109        68.0     3013  17.2
#
#    Under_Five_Deaths  Polio  Tot_Exp  Diphtheria  HIV/AIDS         GDP  \
# 0                 83    6.0     8.16        65.0       0.1  584.259210
# ...

# %%
sns.jointplot(x='Life_Expectancy', y='Year', data=df, alpha=0.5)

# %%
#In order to see all the plots
'''sns.pairplot(df,
             kind='scatter',
             plot_kws={'alpha':0.4},
             diag_kws={'alpha':0.55, 'bins':40})'''

# %%
df.dtypes
# Out:
# Country                      object
# Year                          int64
# Status                       object
# Life_Expectancy             float64
# Adult_Mortality             float64
# Infant_Deaths                 int64
# Alcohol                     float64
# Percentage_Exp              float64
# HepatitisB                  float64
# Measles                       int64
# BMI                         float64
# Under_Five_Deaths             int64
# Polio                       float64
# Tot_Exp                     float64
# Diphtheria                  float64
# HIV/AIDS                    float64
# GDP                         float64
# Population                  float64
# thinness_1to19_years        float64
# thinness_5to9_years         float64
# Income_Comp_Of_Resources    float64
# Schooling                   float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.head()
# Out:
#        Country  Year      Status  Life_Expectancy  Adult_Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant_Deaths  Alcohol  Percentage_Exp  HepatitisB  Measles   BMI  \
# 0             62     0.01       71.279624        65.0     1154  19.1
# 1             64     0.01       73.523582        62.0      492  18.6
# 2             66     0.01       73.219243        64.0      430  18.1
# 3             69     0.01       78.184215        67.0     2787  17.6
# 4             71     0.01        7.097109        68.0     3013  17.2
#
#    Under_Five_Deaths  Polio  Tot_Exp  Diphtheria  HIV/AIDS         GDP  \
# 0                 83    6.0     8.16        65.0       0.1  584.259210
# ...

# %%
lencoder = LabelEncoder()
df['Country'] = lencoder.fit_transform(df['Country'])
df['Status'] = lencoder.fit_transform(df['Status'])

# %%
df.head()
# Out:
#    Country  Year  Status  Life_Expectancy  Adult_Mortality  Infant_Deaths  \
# 0        0  2015       1             65.0            263.0             62
# 1        0  2014       1             59.9            271.0             64
# 2        0  2013       1             59.9            268.0             66
# 3        0  2012       1             59.5            272.0             69
# 4        0  2011       1             59.2            275.0             71
#
#    Alcohol  Percentage_Exp  HepatitisB  Measles   BMI  Under_Five_Deaths  \
# 0     0.01       71.279624        65.0     1154  19.1                 83
# 1     0.01       73.523582        62.0      492  18.6                 86
# 2     0.01       73.219243        64.0      430  18.1                 89
# 3     0.01       78.184215        67.0     2787  17.6                 93
# 4     0.01        7.097109        68.0     3013  17.2                 97
#
#    Polio  Tot_Exp  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# **Training**

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['Country', 'Year', 'Status', 'Adult_Mortality', 'Alcohol', 'Percentage_Exp',
       'HepatitisB', 'Measles', 'BMI', 'Polio', 'Tot_Exp',	'Diphtheria',	'GDP',
       'Population', 'thinness_1to19_years', 'thinness_5to9_years','Income_Comp_Of_Resources','Schooling']]
y = df['Life_Expectancy']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state= 42)

# %%
X_test
# Out:
#       Country  Year  Status  Adult_Mortality  Alcohol  Percentage_Exp  \
# 2546      167  2006       1            123.0     0.97      122.652333
# 650        40  2006       0            113.0    11.83     1555.651986
# 1740      112  2007       1            125.0     4.98      678.518894
# 177        11  2014       1              7.0     1.57      367.255674
# 1377       87  2000       1            428.0     1.51        0.681686
# ...       ...   ...     ...              ...      ...             ...
# 1241       79  2008       1            167.0     0.17      192.156300
# 1456       92  2001       0            228.0     6.68      332.275171
# 123         7  2004       0             69.0     9.84      588.568371
# 2509      165  2011       0             58.0     7.40    11477.667100
# 1728      111  2003       1            271.0     1.31       56.056864
#
#       HepatitisB  Measles   BMI  Polio  Tot_Exp  Diphtheria           GDP  \
# ...

# %%
y_train
# Out:
# 1641    80.0
# 618     55.3
# 406     56.9
# 1094    57.1
# 1788    64.5
#         ...
# 1638    87.0
# 1095    56.7
# 1130    61.8
# 1294    79.9
# 860     59.4
# Name: Life_Expectancy, Length: 2056, dtype: float64

# %%
y_test
# Out:
# 2546    73.7
# 650     75.9
# 1740    74.2
# 177     76.8
# 1377    51.9
#         ...
# 1241    69.3
# 1456    69.9
# 123     86.0
# 2509    81.7
# 1728    64.0
# Name: Life_Expectancy, Length: 882, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression() # Calling the function we're just imported

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Results**

# %%
lm.coef_
# Out:
# array([-1.47691389e-03,  4.85745954e-02, -1.76158606e+00, -3.01823361e-02,
#        -1.90284233e-02,  5.79067946e-05, -1.49039950e-02, -3.92396922e-05,
#         4.99367664e-02,  2.46773969e-02, -2.18046688e-02,  4.69623814e-02,
#         3.07911836e-05,  2.71787945e-09, -1.09141543e-01,  9.49841163e-03,
#         7.15442267e+00,  6.42953530e-01])

# %%
#Score
lm.score(X,y)
# Out:
# 0.7635215542950637

# %%
# The coefficients in a dataframe
cdf = pd.DataFrame(lm.coef_,X.columns,columns=['Coef'])
print(cdf)
# Out:
#                                   Coef
# Country                  -1.476914e-03
# Year                      4.857460e-02
# Status                   -1.761586e+00
# Adult_Mortality          -3.018234e-02
# Alcohol                  -1.902842e-02
# Percentage_Exp            5.790679e-05
# HepatitisB               -1.490399e-02
# Measles                  -3.923969e-05
# BMI                       4.993677e-02
# Polio                     2.467740e-02
# Tot_Exp                  -2.180467e-02
# Diphtheria                4.696238e-02
# GDP                       3.079118e-05
# Population                2.717879e-09
# thinness_1to19_years     -1.091415e-01
# thinness_5to9_years       9.498412e-03
# Income_Comp_Of_Resources  7.154423e+00
# Schooling                 6.429535e-01
